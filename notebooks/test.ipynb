# %%
import numpy as np

path = [(0,0), (1,0), (0,1)]
path = np.asarray(path, dtype=float)
path.shape
# Out:
# (3, 2)

# %%
four = [
            (0,      0, 2),     # start pos
            (5.0,  0.0, 2),     # down the ramp
            (5.0, -3.5, 2),     # up the curb
            (4.0, -3.5, 2),     # center of the curb
            (4.0,   -7, 2),     # before the stairs
            (4.0,  -10, 2),      # up the stairs
            (4.0,  -12, 2),     # goal (porch)
        ]

four_np = np.array(four)[-1][-1:]
four_np
# Out:
# array([2.])

# %%
x0 = 0
y0 = 0
x1 = 3
y1 = 3
n = round(np.sqrt((x1-x0)**2 + (y1-y0)**2)/2) + 2
n
# Out:
# 4
